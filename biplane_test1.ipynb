# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext zipline
# Out:
# /Users/notableprep/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# %%zipline --start 2015-1-1 --end 2015-2-1
# from zipline.api import symbol, order, record, symbols, sid
# def initialize(context):
#     context.message = 'hello'
#     context.aapl = sid(24)
#
# def handle_data(context, data):
#     print context.aapl
# Out:
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
# Equity(24 [ALL])
#                      algo_volatility  algorithm_period_return  alpha  \
# 2015-01-02 21:00:00              NaN                        0    NaN
# 2015-01-05 21:00:00                0                        0      0
# 2015-01-06 21:00:00                0                        0      0
# 2015-01-07 21:00:00                0                        0      0
# 2015-01-08 21:00:00                0                        0      0
# 2015-01-09 21:00:00                0                        0      0
# 2015-01-12 21:00:00                0                        0      0
# ...

# %%
# %%zipline --start 2015-1-1 --end 2015-2-1
# from zipline.api import symbol, order, record, symbols, sid
#
#
# def initialize(context):
#     context.aapl = sid(24)
#     context.spy = symbol('F')
#
#
# def handle_data(context, data):
#     if data.can_trade(context.aapl):
#         order_target_percent(context.aapl, 0.60)
#
#     if data.can_trade(context.spy):
#         order_target_percent(context.spy, -0.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-82d38dc29d6d> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'zipline', u'--start 2015-1-1 --end 2015-2-1', u"from zipline.api import symbol, order, record, symbols, sid\n\n\ndef initialize(context):\n    context.aapl = sid(24)\n    context.spy = symbol('F')\n\n\ndef handle_data(context, data):\n    if data.can_trade(context.aapl):\n        order_target_percent(context.aapl, 0.60)\n        \n    if data.can_trade(context.spy):\n        order_target_percent(context.spy, -0.4)")
#
# /Users/notableprep/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
# ...

# %%
aapl = _.copy()

# %%
aapl.head()
# Out:
#                        AAPL  algo_volatility  algorithm_period_return  \
# 2015-01-02 21:00:00  109.33              NaN             0.000000e+00
# 2015-01-05 21:00:00  106.25     1.122497e-06            -1.000000e-07
# 2015-01-06 21:00:00  106.26     8.742998e-07            -1.900000e-07
# 2015-01-07 21:00:00  107.75     2.337289e-05             2.690000e-06
# 2015-01-08 21:00:00  111.89     8.513024e-05             1.501000e-05
#
#                             alpha  benchmark_period_return  \
# 2015-01-02 21:00:00           NaN                -0.000535
# 2015-01-05 21:00:00  7.695753e-07                -0.018585
# 2015-01-06 21:00:00 -2.483339e-06                -0.027829
# 2015-01-07 21:00:00  2.636176e-04                -0.015715
# 2015-01-08 21:00:00  7.251936e-04                 0.001751
#
#                      benchmark_volatility      beta  capital_used  \
# 2015-01-02 21:00:00                   NaN       NaN           0.0
# ...

# %%
aapl.plot()

# %%
aapl['ending_value'].plot()

# %%
aapl.iloc[-1]
# Out:
# AAPL                                                                  153.18
# algo_volatility                                                   0.00787825
# algorithm_period_return                                            0.0220359
# alpha                                                             0.00688974
# benchmark_period_return                                             0.184003
# benchmark_volatility                                                0.134467
# beta                                                               0.0275186
# capital_used                                                         -1532.8
# ending_cash                                                      9.29056e+06
# ending_exposure                                                       929803
# ending_value                                                          929803
# excess_return                                                    -6.4079e-05
# ...

# %%
aapl['ending_cash'].plot()

# %%
aapl['returns'].cumsum().plot()

# %%
res = pd.read_pickle('res2.pkl')

# %%
res.head()
# Out:
#                        AAPL  algo_volatility  algorithm_period_return  \
# 2015-01-02 21:00:00  109.33              NaN                 0.000000
# 2015-01-05 21:00:00  106.25         0.000011                -0.000001
# 2015-01-06 21:00:00  106.26         0.000009                -0.000002
# 2015-01-07 21:00:00  107.75         0.000234                 0.000027
# 2015-01-08 21:00:00  111.89         0.000851                 0.000150
#
#                         alpha  benchmark_period_return  benchmark_volatility  \
# 2015-01-02 21:00:00       NaN                -0.000535                   NaN
# 2015-01-05 21:00:00  0.000008                -0.018585              0.196712
# 2015-01-06 21:00:00 -0.000025                -0.027829              0.139101
# 2015-01-07 21:00:00  0.002636                -0.015715              0.206972
# 2015-01-08 21:00:00  0.007252                 0.001751              0.236040
#
#                          beta  capital_used  ending_cash  ending_exposure  \
# ...

# %%
res.transactions.iloc[1
                     ]
# Out:
# [{'amount': 10,
#   'commission': None,
#   'dt': Timestamp('2015-01-05 21:00:00+0000', tz='UTC'),
#   'order_id': '2cfcbc0f891d44528ada1ad3a8eb3420',
#   'price': 106.25000000000026,
#   'sid': Equity(0, symbol=u'AAPL', asset_name=u'Apple Inc', exchange=u'QUANDL', start_date=Timestamp('1980-12-12 00:00:00+0000', tz='UTC'), end_date=Timestamp('2017-07-13 00:00:00+0000', tz='UTC'), first_traded=None, auto_close_date=Timestamp('2017-07-14 00:00:00+0000', tz='UTC'), exchange_full=u'QUANDL')}]
